# %%
import numpy as np

matrix = np.array([
    [5, 8, 2, 7],
    [1, 9, 4, 3],
    [6, 0, 11, 10],
    [12, 13, 14, 15]
])

print("The second row:", matrix[1, :])

print("The third column:", matrix[:, 2])

sub_table = matrix[1:3, 1:3]
print("Sub-table (R2-R3, C2-C3):\n", sub_table)
# Out:
# The second row: [1 9 4 3]
# The third column: [ 2  4 11 14]
# Sub-table (R2-R3, C2-C3):
#  [[ 9  4]
#  [ 0 11]]

# %%
import numpy as np

scores = np.array([
    [70, 80, 90],
    [60, 75, 85],
    [88, 92, 79],
    [55, 65, 72]
])

scores[:, 1] += 5
print("Scores after increasing Physics marks:\n", scores)

scores[0, :] = [100, 100, 100]
print("\nScores after replacing first student's marks:\n", scores)

scores[:, 2] = 0
print("\nScores after setting CS column to zero:\n", scores)
# Out:
# Scores after increasing Physics marks:
#  [[70 85 90]
#  [60 80 85]
#  [88 97 79]
#  [55 70 72]]
#
# Scores after replacing first student's marks:
#  [[100 100 100]
#  [ 60  80  85]
#  [ 88  97  79]
#  [ 55  70  72]]
#
# Scores after setting CS column to zero:
#  [[100 100   0]
#  [ 60  80   0]
#  [ 88  97   0]
#  [ 55  70   0]]

# %%
import numpy as np

A = np.array([[1, 2], [3, 4]])
B = np.array([[5, 6], [7, 8]])
v = np.array([2, 4])

print("Element-wise multiplication (A * B):\n", A * B)

print("\nMatrix multiplication (A @ B):\n", A @ B)

print("\nA * v using broadcasting:\n", A * v)
# Out:
# Element-wise multiplication (A * B):
#  [[ 5 12]
#  [21 32]]
#
# Matrix multiplication (A @ B):
#  [[19 22]
#  [43 50]]
#
# A * v using broadcasting:
#  [[ 2  8]
#  [ 6 16]]

# %%
import numpy as np

np.random.seed(42)
random_matrix = np.random.randint(-5, 6, size=(4, 4))
print("Random 4x4 Matrix:\n", random_matrix)

unique_vals, counts = np.unique(random_matrix, return_counts=True)
print("\nUnique values:", unique_vals)
print("Counts of each unique value:", counts)

print("\nUnique rows of random matrix:\n", np.unique(random_matrix, axis=0))

a = np.array([[1, 0, 0], [1, 0, 0], [2, 3, 4]])
unique_rows = np.unique(a, axis=0)
print("\nUnique rows of array 'a':\n", unique_rows)
# Out:
# Random 4x4 Matrix:
#  [[ 1 -2  5  2]
#  [-1  1  4 -3]
#  [ 1  5  5  2]
#  [-1 -2  2  2]]
#
# Unique values: [-3 -2 -1  1  2  4  5]
# Counts of each unique value: [1 2 2 3 4 1 3]
#
# Unique rows of random matrix:
#  [[-1 -2  2  2]
#  [-1  1  4 -3]
#  [ 1 -2  5  2]
#  [ 1  5  5  2]]
#
# Unique rows of array 'a':
#  [[1 0 0]
#  [2 3 4]]

# %%
import numpy as np

x = np.array([2, 0, 1, 5, 4, 1, 9])
A = np.array([[3, 8, 1], [6, 2, 9]])

indices = np.argsort(x)
print("Indices of sorted x:", indices)
print("Sorted x using indices:", x[indices])

min_loc = np.unravel_index(A.argmin(), A.shape)
print("\nMinimum value location in A (row, col):", min_loc)

print("\nIndices where x > 3:", np.where(x > 3))

parts = np.split(x, [2, 5])
print("\nSplit x into 3 parts:", parts)

expanded_x = np.expand_dims(x, axis=0)
print("\nExpanded x shape:", expanded_x.shape)

squeezed_x = np.squeeze(expanded_x)
print("Squeezed x shape back to:", squeezed_x.shape)
# Out:
# Indices of sorted x: [1 2 5 0 4 3 6]
# Sorted x using indices: [0 1 1 2 4 5 9]
#
# Minimum value location in A (row, col): (np.int64(0), np.int64(2))
#
# Indices where x > 3: (array([3, 4, 6]),)
#
# Split x into 3 parts: [array([2, 0]), array([1, 5, 4]), array([1, 9])]
#
# Expanded x shape: (1, 7)
# Squeezed x shape back to: (7,)
